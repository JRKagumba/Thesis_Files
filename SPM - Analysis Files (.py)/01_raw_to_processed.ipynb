# %%
import os
import sys
import glob

import shutil 
import pandas as pd

# %%
xsens_raw =r"E:\Data\Jarrod_Thesis\Xsens\raw_data"
xsens_processed = r"E:\Data\Jarrod_Thesis\Xsens\processed_data"

for subject in os.scandir(xsens_raw):

    subject_path=subject.path
    subject_name=subject.name

    for task in os.scandir(subject_path):
        if task.is_dir():
            task_path=task.path
            task_name=task.name

            dataframes_dict={}
            for file in os.scandir(task_path):
                cycle_name=file.name[13:16]
                cycle_path=file.path


                xls = pd.ExcelFile(cycle_path)
                dataframes_dict[cycle_name]=pd.read_excel(xls, 'Center of Mass')

            new_task_path=os.path.join(xsens_processed,subject_name,task_name)

            get_com_data(dataframes_dict,new_task_path)
            # shutil.rmtree(os.path.join(new_task_path,'Elbow'), ignore_errors=True)
            

            

            


# xls = pd.ExcelFile(file_path)
# subject_csv = pd.read_excel(xls, 'Joint Angles ZXY')
# subject_COM_csv = pd.read_excel(xls, 'Center of Mass')

    # print(task_set)
# Out:
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T01\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T01\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T01\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T02\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T02\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T02\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T03\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T03\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T03\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T04\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T04\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T04\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T05\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T05\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T05\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T06\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T06\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T06\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T07\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T07\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T07\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T08\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T08\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T08\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T09\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T09\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T09\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T10\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T10\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T10\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T11\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T11\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T11\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T12\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T12\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T12\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T13\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T13\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T13\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T14\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T14\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S01\T14\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T01\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T01\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T01\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T02\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T02\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T02\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T03\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T03\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T03\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T04\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T04\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T04\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T05\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T05\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T05\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T06\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T06\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T06\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T07\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T07\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T07\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T08\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T08\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T08\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T09\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T09\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T09\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T10\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T10\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T10\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T11\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T11\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T11\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T12\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T12\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T12\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T13\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T13\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T13\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T14\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T14\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S02\T14\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T01\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T01\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T01\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T02\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T02\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T02\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T03\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T03\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T03\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T04\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T04\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T04\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T05\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T05\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T05\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T06\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T06\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T06\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T07\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T07\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T07\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T08\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T08\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T08\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T09\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T09\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T09\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T10\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T10\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T10\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T11\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T11\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T11\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T12\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T12\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T12\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T13\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T13\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T13\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T14\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T14\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S03\T14\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T01\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T01\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T01\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T02\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T02\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T02\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T03\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T03\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T03\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T04\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T04\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T04\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T05\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T05\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T05\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T06\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T06\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T06\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T07\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T07\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T07\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T08\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T08\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T08\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T09\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T09\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T09\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T10\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T10\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T10\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T11\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T11\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T11\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T12\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T12\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T12\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T13\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T13\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T13\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T14\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T14\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S04\T14\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T01\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T01\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T01\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T02\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T02\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T02\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T03\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T03\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T03\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T04\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T04\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T04\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T05\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T05\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T05\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T06\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T06\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T06\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T07\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T07\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T07\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T08\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T08\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T08\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T09\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T09\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T09\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T10\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T10\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T10\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T11\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T11\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T11\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T12\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T12\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T12\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T13\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T13\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T13\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T14\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T14\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S05\T14\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T01\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T01\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T01\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T02\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T02\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T02\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T03\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T03\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T03\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T04\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T04\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T04\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T05\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T05\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T05\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T06\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T06\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T06\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T07\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T07\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T07\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T08\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T08\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T08\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T09\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T09\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T09\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T10\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T10\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T10\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T11\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T11\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T11\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T12\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T12\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T12\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T13\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T13\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T13\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T14\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T14\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S06\T14\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T01\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T01\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T01\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T02\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T02\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T02\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T03\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T03\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T03\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T04\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T04\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T04\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T05\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T05\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T05\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T06\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T06\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T06\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T07\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T07\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T07\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T08\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T08\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T08\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T09\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T09\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T09\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T10\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T10\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T10\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T11\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T11\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T11\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T12\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T12\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T12\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T13\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T13\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T13\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T14\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T14\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S07\T14\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T01\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T01\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T01\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T02\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T02\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T02\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T03\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T03\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T03\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T04\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T04\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T04\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T05\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T05\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T05\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T06\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T06\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T06\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T07\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T07\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T07\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T08\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T08\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T08\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T09\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T09\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T09\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T10\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T10\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T10\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T11\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T11\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T11\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T12\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T12\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T12\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T13\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T13\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T13\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T14\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T14\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S08\T14\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T01\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T01\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T01\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T02\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T02\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T02\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T03\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T03\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T03\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T04\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T04\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T04\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T05\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T05\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T05\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T06\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T06\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T06\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T07\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T07\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T07\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T08\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T08\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T08\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T09\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T09\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T09\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T10\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T10\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T10\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T11\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T11\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T11\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T12\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T12\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T12\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T13\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T13\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T13\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T14\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T14\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S09\T14\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T01\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T01\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T01\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T02\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T02\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T02\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T03\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T03\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T03\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T04\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T04\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T04\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T05\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T05\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T05\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T06\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T06\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T06\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T07\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T07\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T07\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T08\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T08\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T08\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T09\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T09\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T09\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T10\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T10\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T10\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T11\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T11\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T11\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T12\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T12\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T12\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T13\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T13\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T13\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T14\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T14\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S10\T14\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T01\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T01\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T01\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T02\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T02\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T02\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T03\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T03\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T03\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T04\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T04\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T04\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T05\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T05\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T05\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T06\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T06\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T06\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T07\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T07\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T07\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T08\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T08\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T08\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T09\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T09\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T09\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T10\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T10\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T10\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T11\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T11\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T11\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T12\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T12\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T12\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T13\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T13\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T13\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T14\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T14\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S11\T14\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T01\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T01\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T01\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T02\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T02\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T02\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T03\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T03\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T03\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T04\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T04\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T04\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T05\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T05\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T05\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T06\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T06\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T06\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T07\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T07\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T07\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T08\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T08\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T08\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T09\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T09\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T09\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T10\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T10\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T10\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T11\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T11\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T11\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T12\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T12\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T12\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T13\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T13\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T13\COM\CoM pos z
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T14\COM\CoM pos x
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T14\COM\CoM pos y
# New directory created at E:\Data\Jarrod_Thesis\Xsens\processed_data\S12\T14\COM\CoM pos z

# %%
def get_com_data(dataframes_dict,new_task_path):
    COM={}
    joint='COM'
    for cycle_name, dataframe in dataframes_dict.items():

        for columnName in dataframe.iloc[:,1:4].columns:
            if columnName not in COM.keys():
                COM[columnName]={}
        
        for (columnName, columnData) in dataframe.iloc[:,1:4].iteritems():  
            COM[columnName][columnName+'_'+cycle_name]=pd.Series(columnData)


    for columnName in COM.keys():
        df= pd.DataFrame(COM[columnName])
        columnName=columnName.replace("/", "_")
        new_dir=os.path.join(new_task_path,joint,columnName)
        os.makedirs(new_dir, exist_ok = True)
        df.to_csv(os.path.join(new_dir, f'{columnName}.csv')) 
        print(f'New directory created at {new_dir}')

# %%
sample_path=r"E:\Data\Jarrod_Thesis\Xsens\raw_data\S07\T05\XSEN_S07_T05_C02.xlsx"

xls = pd.ExcelFile(sample_path)
pd.read_excel(xls, 'Center of Mass').iloc[:,1:4]
# Out:
#       CoM pos x  CoM pos y  CoM pos z
# 0     -0.365585  -0.686106   1.091097
# 1     -0.365505  -0.686211   1.091162
# 2     -0.365426  -0.686317   1.091227
# 3     -0.365356  -0.686421   1.091286
# 4     -0.365299  -0.686527   1.091338
# ...         ...        ...        ...
# 3544  -0.416426  -0.733837   1.083200
# 3545  -0.416573  -0.734543   1.083403
# 3546  -0.416723  -0.735180   1.083589
# 3547  -0.416929  -0.735916   1.083812
# 3548  -0.417138  -0.736575   1.084015
#
# [3549 rows x 3 columns]

# %%
def get_shoulder_data(dataframes_dict,new_task_path):
    
    joint='Shoulder'

    for orientation in ['Left','Right']:
        SHOULDER={}
        if orientation == 'Left':
            for cycle_name, dataframe in dataframes_dict.items():

                for columnName in dataframe.iloc[:,23:24].columns:
                    if columnName not in SHOULDER.keys():
                        SHOULDER[columnName]={}
                
                for (columnName, columnData) in dataframe.iloc[:,23:24].iteritems():  
                    SHOULDER[columnName][columnName+'_'+cycle_name]=pd.Series(columnData)


            for columnName in SHOULDER.keys():
                df= pd.DataFrame(SHOULDER[columnName])
                new_dir=os.path.join(new_task_path,joint,orientation,columnName)
                os.makedirs(new_dir, exist_ok = True)
                df.to_csv(os.path.join(new_dir, f'{columnName}.csv')) 
                print(f'New directory created at {new_dir}')
        
        if orientation == 'Right':
            for cycle_name, dataframe in dataframes_dict.items():

                for columnName in dataframe.iloc[:,35:36].columns:
                    if columnName not in SHOULDER.keys():
                        SHOULDER[columnName]={}
                
                for (columnName, columnData) in dataframe.iloc[:,35:36].iteritems():  
                    SHOULDER[columnName][columnName+'_'+cycle_name]=pd.Series(columnData)


            for columnName in SHOULDER.keys():
                df= pd.DataFrame(SHOULDER[columnName])
                new_dir=os.path.join(new_task_path,joint,orientation,columnName)
                os.makedirs(new_dir, exist_ok = True)
                df.to_csv(os.path.join(new_dir, f'{columnName}.csv')) 
                print(f'New directory created at {new_dir}')

# %%
def get_elbow_data(dataframes_dict,new_task_path):
    
    joint='Elbow'

    for orientation in ['Left','Right']:
        ELBOW={}
        if orientation == 'Left':
            for cycle_name, dataframe in dataframes_dict.items():

                for columnName in dataframe.iloc[:,28:29].columns:
                    if columnName not in ELBOW.keys():
                        ELBOW[columnName]={}
                
                for (columnName, columnData) in dataframe.iloc[:,28:29].iteritems():  
                    ELBOW[columnName][columnName+'_'+cycle_name]=pd.Series(columnData)


            for columnName in ELBOW.keys():
                df= pd.DataFrame(ELBOW[columnName])
                new_dir=os.path.join(new_task_path,joint,orientation,columnName)
                os.makedirs(new_dir, exist_ok = True)
                df.to_csv(os.path.join(new_dir, f'{columnName}.csv')) 
                print(f'New directory created at {new_dir}')
        
        if orientation == 'Right':
            for cycle_name, dataframe in dataframes_dict.items():

                for columnName in dataframe.iloc[:,41:42].columns:
                    if columnName not in ELBOW.keys():
                        ELBOW[columnName]={}
                
                for (columnName, columnData) in dataframe.iloc[:,41:42].iteritems():  
                    ELBOW[columnName][columnName+'_'+cycle_name]=pd.Series(columnData)


            for columnName in ELBOW.keys():
                df= pd.DataFrame(ELBOW[columnName])
                new_dir=os.path.join(new_task_path,joint,orientation,columnName)
                os.makedirs(new_dir, exist_ok = True)
                df.to_csv(os.path.join(new_dir, f'{columnName}.csv')) 
                print(f'New directory created at {new_dir}')

# %%
def get_com_data(dataframes_dict,new_task_path):
    COM={}
    joint='COM'
    for cycle_name, dataframe in dataframes_dict.items():

        for columnName in dataframe.iloc[:,-3:].columns:
            if columnName not in COM.keys():
                COM[columnName]={}
        
        for (columnName, columnData) in dataframe.iloc[:,-3:].iteritems():  
            COM[columnName][columnName+'_'+cycle_name]=pd.Series(columnData)


    for columnName in COM.keys():
        df= pd.DataFrame(COM[columnName])
        new_dir=os.path.join(new_task_path,joint,columnName)
        os.makedirs(new_dir, exist_ok = True)
        df.to_csv(os.path.join(new_dir, f'{columnName}.csv')) 
        print(f'New directory created at {new_dir}')

# %%
def get_trunk_data(dataframes_dict,new_task_path):
    TRUNK={}
    joint='Trunk'
    for cycle_name, dataframe in dataframes_dict.items():

        for columnName in dataframe.iloc[:,13:14].columns:
            if columnName not in TRUNK.keys():
                TRUNK[columnName]={}
        
        for (columnName, columnData) in dataframe.iloc[:,13:14].iteritems():  
            TRUNK[columnName][columnName+'_'+cycle_name]=pd.Series(columnData)


    for columnName in TRUNK.keys():
        df= pd.DataFrame(TRUNK[columnName])
        new_dir=os.path.join(new_task_path,joint,columnName)
        os.makedirs(new_dir, exist_ok = True)
        df.to_csv(os.path.join(new_dir, f'{columnName}.csv')) 
        print(f'New directory created at {new_dir}')

# %%
def get_neck_data(dataframes_dict,new_task_path):
    NECK={}
    joint='Neck'
    for cycle_name, dataframe in dataframes_dict.items():

        for columnName in dataframe.iloc[:,18:19].columns:
            if columnName not in NECK.keys():
                NECK[columnName]={}
        
        for (columnName, columnData) in dataframe.iloc[:,18:19].iteritems():  
            NECK[columnName][columnName+'_'+cycle_name]=pd.Series(columnData)


    for columnName in NECK.keys():
        df= pd.DataFrame(NECK[columnName])
        new_dir=os.path.join(new_task_path,joint,columnName)
        os.makedirs(new_dir, exist_ok = True)
        df.to_csv(os.path.join(new_dir, f'{columnName}.csv')) 
        print(f'New directory created at {new_dir}')

# %%
    # task_set=set()
    # for file in os.listdir(directory):
    #     if file[:4]=='XSEN':
    #         task_set.add(file[9:12])
    


    # for task in task_set:
    #     path = os.path.join(directory, task)
    #     os.mkdir(path)

    #     for item in os.scandir(directory):
            
    #         if (item.is_file()) and (task in item.name):
                
    #             source=item.path
    #             destination= os.path.join(directory, task, item.name)
                

    #             shutil.move(source, destination)
    #             print(f"{item.name} has been moved to {task}")
